# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# set the max columns to none
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Automobile_data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df[df["price"] =="?"]
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 9            0                 ?     audi       gas      turbo          two
# 44           1                 ?    isuzu       gas        std          two
# 45           0                 ?    isuzu       gas        std         four
# 129          1                 ?  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 9    hatchback          4wd           front        99.5   178.2   67.9
# 44       sedan          fwd           front        94.5   155.9   63.6
# 45       sedan          fwd           front        94.5   155.9   63.6
# 129  hatchback          rwd           front        98.4   175.7   72.3
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# 9      52.0         3053         ohc             five          131
# 44     52.0         1874         ohc             four           90
# ...

# %% [markdown]
# ### Types of Cars

# %%
print(f'There are {df["make"].nunique()} types of cars in this dataset')
# Out:
# There are 22 types of cars in this dataset

# %% [markdown]
# ### Coloumns with "?"

# %%
# normalized-losses
# num-of-doors
# bore
# stroke
# peak-rpm
# price

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# ### Fixing rows with "?"

# %%
df[df["normalized-losses"] == "?"].shape[0]
# Out:
# 41

# %%
df[df["num-of-doors"] == "?"].shape[0]
# Out:
# 2

# %%
df[df["bore"] == "?"].shape[0]
# Out:
# 4

# %%
df[df["stroke"] == "?"].shape[0]
# Out:
# 4

# %%
df[df["peak-rpm"] == "?"].shape[0]
# Out:
# 2

# %%
df[df["price"] == "?"].shape[0]
# Out:
# 4

# %% [markdown]
# ### Fixing "normalized-losses" column

# %%
# "?" is an object so it cannot be converted to median.
# We have to first replace it with 0 then convert the column into 
# integer and then replace 0 with median value.

# %%
df["normalized-losses"] = df["normalized-losses"].replace(to_replace ="?",
                 value =0)

# %%
df["normalized-losses"].astype(int)
# Out:
# 0        0
# 1        0
# 2        0
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: int64

# %%
df["normalized-losses"].median()
# Out:
# 103.0

# %%
df["normalized-losses"].replace({0:df["normalized-losses"].median()},inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# # Fixing "price" column

# %%
df=df[df["price"]!="?"] #drop raw where price of value is "?". Because price is the targeted feature

# %%
df.shape
# Out:
# (201, 26)

# %%
df["price"].dtype
# Out:
# dtype('O')

# %%
df["price"]=df["price"].astype(int)

# %%
df["price"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Analysis

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df["price"].unique()
# Out:
# array([13495, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 16430,
#        16925, 20970, 21105, 24565, 30760, 41315, 36880,  5151,  6295,
#         6575,  5572,  6377,  7957,  6229,  6692,  7609,  8558,  8921,
#        12964,  6479,  6855,  5399,  6529,  7129,  7295,  7895,  9095,
#         8845, 10295, 12945, 10345,  6785, 11048, 32250, 35550, 36000,
#         5195,  6095,  6795,  6695,  7395, 10945, 11845, 13645, 15645,
#         8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552, 28248,
#        28176, 31600, 34184, 35056, 40960, 45400, 16503,  5389,  6189,
#         6669,  7689,  9959,  8499, 12629, 14869, 14489,  6989,  8189,
#         9279,  5499,  7099,  6649,  6849,  7349,  7299,  7799,  7499,
#         7999,  8249,  8949,  9549, 13499, 14399, 17199, 19699, 18399,
#        11900, 13200, 12440, 13860, 15580, 16900, 16695, 17075, 16630,
#        17950, 18150, 12764, 22018, 32528, 34028, 37028,  9295,  9895,
# ...

# %%
df["price"].max()
# Out:
# 45400

# %%
df["city-mpg"].unique()
# Out:
# array([21, 19, 24, 18, 17, 23, 20, 16, 15, 47, 38, 37, 31, 49, 30, 27, 25,
#        13, 26, 36, 22, 14, 45, 28, 32, 35, 34, 29, 33])

# %%
sns.boxplot(x="city-mpg",data=df)
# Out:
# <AxesSubplot: xlabel='city-mpg'>

# %%
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
# figsize should be higher
plt.figure(figsize=(10,5))
plt.xticks(rotation ='vertical')
sns.countplot(x="make",data=df)
# Out:
# <AxesSubplot: xlabel='make', ylabel='count'>

# %%
df["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df["fuel-type"].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel-type, dtype: int64

# %%
sns.countplot(x="fuel-type",data=df)
# Out:
# <AxesSubplot: xlabel='fuel-type', ylabel='count'>

# %%
df["body-style"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df["body-style"].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
sns.countplot(x="body-style",data=df)
# Out:
# <AxesSubplot: xlabel='body-style', ylabel='count'>

# %%
df["price"].max()
# Out:
# 45400

# %%
df["price"].min()
# Out:
# 5118

# %%
df["engine-type"].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf'], dtype=object)

# %%
df["engine-type"].value_counts()
# Out:
# ohc      145
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# Name: engine-type, dtype: int64

# %%
sns.countplot(x="engine-type",data=df)
# Out:
# <AxesSubplot: xlabel='engine-type', ylabel='count'>

# %%
df["num-of-doors"].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
df["num-of-doors"].value_counts()
# Out:
# four    113
# two      86
# ?         2
# Name: num-of-doors, dtype: int64

# %%
sns.countplot(x="num-of-doors",data=df)
# Out:
# <AxesSubplot: xlabel='num-of-doors', ylabel='count'>

# %%
df[df["num-of-doors"]=="?"]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 27          1               148  dodge       gas      turbo            ?
# 63          0             103.0  mazda    diesel        std            ?
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 27      sedan          fwd           front        93.7   157.3   63.8    50.6
# 63      sedan          fwd           front        98.8   177.8   66.5    55.5
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 27         2191         ohc             four           98        mpfi  3.03
# 63         2443         ohc             four          122         idi  3.39
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 27   3.39                7.6        102     5500        24           30   8558
# 63   3.39               22.7         64     4650        36           42  10795

# %%
df.corr()
# Out:
# /tmp/ipykernel_11303/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.535987 -0.365404 -0.242423 -0.550160
# wheel-base         -0.535987    1.000000  0.876024  0.814507  0.590742
# length             -0.365404    0.876024  1.000000  0.857170  0.492063
# width              -0.242423    0.814507  0.857170  1.000000  0.306002
# height             -0.550160    0.590742  0.492063  0.306002  1.000000
# curb-weight        -0.233118    0.782097  0.880665  0.866201  0.307581
# engine-size        -0.110581    0.572027  0.685025  0.729436  0.074694
# compression-ratio  -0.182196    0.250313  0.159733  0.189867  0.259737
# ...

# %%
df["engine-size"].nunique()
# Out:
# 43

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="engine-size",data=df)
# Out:
# <AxesSubplot: xlabel='engine-size', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="horsepower",data=df)
# Out:
# <AxesSubplot: xlabel='horsepower', ylabel='count'>

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="horsepower",data=df)
# Out:
# <AxesSubplot: xlabel='horsepower', ylabel='count'>

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df["engine-location"].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df["engine-location"].value_counts()
# Out:
# front    198
# rear       3
# Name: engine-location, dtype: int64

# %%
sns.countplot(x=df["engine-location"],data=df)
# Out:
# <AxesSubplot: xlabel='engine-location', ylabel='count'>

# %%
df[df["engine-location"]=="rear"]
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 126          3             103.0  porsche       gas        std          two
# 127          3             103.0  porsche       gas        std          two
# 128          3             103.0  porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  length  width  \
# 126      hardtop          rwd            rear        89.5   168.9   65.0
# 127      hardtop          rwd            rear        89.5   168.9   65.0
# 128  convertible          rwd            rear        89.5   168.9   65.0
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# 126    51.6         2756        ohcf              six          194
# 127    51.6         2756        ohcf              six          194
# 128    51.6         2800        ohcf              six          194
#
#     fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
print(df.loc[126])
print("\n")
print("----------")
print("\n")
print(df.loc[127])
print("\n")
print("----------")
print("\n")
print(df.loc[128])
# Out:
# symboling                  3
# normalized-losses      103.0
# make                 porsche
# fuel-type                gas
# aspiration               std
# num-of-doors             two
# body-style           hardtop
# drive-wheels             rwd
# engine-location         rear
# wheel-base              89.5
# length                 168.9
# width                   65.0
# height                  51.6
# curb-weight             2756
# engine-type             ohcf
# num-of-cylinders         six
# engine-size              194
# fuel-system             mpfi
# bore                    3.74
# stroke                   2.9
# compression-ratio        9.5
# horsepower               207
# peak-rpm                5900
# city-mpg                  17
# highway-mpg               25
# price                  32528
# Name: 126, dtype: object
#
#
# ----------
#
#
# symboling                  3
# normalized-losses      103.0
# make                 porsche
# fuel-type                gas
# ...

# %%
df["num-of-cylinders"].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df["num-of-cylinders"].value_counts()
# Out:
# four      157
# six        24
# five       10
# two         4
# eight       4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %%
sns.countplot(x="num-of-cylinders",data=df)
# Out:
# <AxesSubplot: xlabel='num-of-cylinders', ylabel='count'>

# %%
df[df["num-of-cylinders"]=="twelve"]
# Out:
#     symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 49          0             103.0  jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 49      sedan          rwd           front       102.0   191.7   70.6    47.8
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 49         3950        ohcv           twelve          326        mpfi  3.54
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 49   2.76               11.5        262     5000        13           17  36000

# %%
df[df["num-of-cylinders"]=="eight"]
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 71         -1             103.0  mercedes-benz       gas        std
# 72          3               142  mercedes-benz       gas        std
# 73          0             103.0  mercedes-benz       gas        std
# 74          1             103.0  mercedes-benz       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 71         four        sedan          rwd           front       115.6   202.6
# 72          two  convertible          rwd           front        96.6   180.3
# 73         four        sedan          rwd           front       120.9   208.1
# 74          two      hardtop          rwd           front       112.0   199.2
#
#     width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 71   71.7    56.5         3740        ohcv            eight          234
# 72   70.5    50.8         3685        ohcv            eight          234
# ...

# %%
df[df["num-of-cylinders"]=="six"]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 2            1             103.0  alfa-romero       gas        std
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# 14           1             103.0          bmw       gas        std
# 15           0             103.0          bmw       gas        std
# 16           0             103.0          bmw       gas        std
# 17           0             103.0          bmw       gas        std
# 47           0               145       jaguar       gas        std
# 48           0             103.0       jaguar       gas        std
# 101          0               128       nissan       gas        std
# 102          0               108       nissan       gas        std
# 103          0               108       nissan       gas        std
# 104          3               194       nissan       gas        std
# ...

# %%
df[df["num-of-cylinders"]=="five"]
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 4            2               164           audi       gas        std
# 5            2             103.0           audi       gas        std
# 6            1               158           audi       gas        std
# 7            1             103.0           audi       gas        std
# 8            1               158           audi       gas      turbo
# 67          -1                93  mercedes-benz    diesel      turbo
# 68          -1                93  mercedes-benz    diesel      turbo
# 69           0                93  mercedes-benz    diesel      turbo
# 70          -1                93  mercedes-benz    diesel      turbo
# 191          0             103.0     volkswagen       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 4           four      sedan          4wd           front        99.4   176.6
# ...

# %%
df[df["num-of-cylinders"]=="four"]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             103.0  alfa-romero       gas        std
# 1            3             103.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# ..         ...               ...          ...       ...        ...
# 198         -2               103        volvo       gas      turbo
# 199         -1                74        volvo       gas      turbo
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df[df["num-of-cylinders"]=="three"]
# Out:
#     symboling normalized-losses       make fuel-type aspiration num-of-doors  \
# 18          2               121  chevrolet       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 18  hatchback          fwd           front        88.4   141.1   60.3    53.2
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 18         1488           l            three           61        2bbl  2.91
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 18   3.03                9.5         48     5100        47           53   5151

# %%
df[df["num-of-cylinders"]=="two"]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
# 58          3               150  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 55  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 56  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 57  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 58  hatchback          rwd           front        95.3   169.0   65.7    49.6
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system bore  \
# 55         2380       rotor              two           70        4bbl    ?
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# # if price is 16500. what should i go for?

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
#df[df["price"]==16500]

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df["length"].unique()
# Out:
# array([168.8, 171.2, 176.6, 177.3, 192.7, 176.8, 189. , 193.8, 197. ,
#        141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. , 163.4,
#        157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7, 159.1,
#        166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3, 208.1,
#        199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4, 173.4,
#        181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 181.5, 186.6,
#        156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7, 166.3, 168.7,
#        176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7, 180.2, 183.1,
#        188.8])

# %%
df["length"].median()
# Out:
# 173.2

# %%
df["length"].mean()
# Out:
# 174.20099502487562

# %%
df["length"].max()
# Out:
# 208.1

# %%
df["length"].min()
# Out:
# 141.1

# %%
sns.scatterplot(x="price",y="engine-size",data=df)
# Out:
# <AxesSubplot: xlabel='price', ylabel='engine-size'>

# %% [markdown]
# # Company Analysis

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             103.0  alfa-romero       gas        std          two
# 1          3             103.0  alfa-romero       gas        std          two
# 2          1             103.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# ### Audi

# %%
gb=df.groupby('make')
audi_df=gb.get_group("audi")

# %%
audi_df.head()
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2               164  audi       gas        std         four
# 4          2               164  audi       gas        std         four
# 5          2             103.0  audi       gas        std          two
# 6          1               158  audi       gas        std         four
# 7          1             103.0  audi       gas        std         four
#
#   body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 3      sedan          fwd           front        99.8   176.6   66.2    54.3
# 4      sedan          4wd           front        99.4   176.6   66.4    54.3
# 5      sedan          fwd           front        99.8   177.3   66.3    53.1
# 6      sedan          fwd           front       105.8   192.7   71.4    55.7
# 7      wagon          fwd           front       105.8   192.7   71.4    55.7
#
# ...

# %%
audi_df["price"]
# Out:
# 3    13950
# 4    17450
# 5    15250
# 6    17710
# 7    18920
# 8    23875
# Name: price, dtype: int64
